# %%
import pandas as pd
import numpy as np
import re
import json
from random import sample
from tqdm import tqdm
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer

# %% [markdown]
# # Generate Lookup table
#
# **Fields only need unqiue:**
#  1. DATA: 'RECVDATE', 'STATE', 'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX', 'RPT_DATE','DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT', 'HOSPITAL', 'HOSPDAYS', 'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE', 'ONSET_DATE', 'NUMDAYS','V_ADMINBY', 'V_FUNDBY','SPLTTYPE', 'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT', 'OFC_VISIT', 'ER_ED_VISIT'
#  2. VAX: 'VAX_TYPE','VAX_MANU','VAX_LOT','VAX_DOSE_SERIES','VAX_ROUTE','VAX_SITE','VAX_NAME'
#
# **Text fields need regx/tokenize:**
#  1. DATA: 'LAB_DATA','OTHER_MEDS', 'CUR_ILL', 'HISTORY', 'PRIOR_VAX','ALLERGIES'
#
# **Equivalent:**
#  1. DATA:'SYMPTOM_TEXT' = SYMPTOMS: Symptoms list

# %%
def vax_name(field):
    value = []
    for x in field:
        x = re.sub(r'\s{1}\(.*\)', '', x)
        x = x.split(' + ')
        value += x[:]
    value = list(set(value))
    return value

# %%
def build_lookup(data, vax, symp):
    datasets = []
    for f in [data, vax, symp]:
        df = pd.read_csv(f, encoding = 'Windows-1252')
        datasets.append(df)
        
    text_fields = ['LAB_DATA','OTHER_MEDS', 'CUR_ILL', 'HISTORY', 'PRIOR_VAX','ALLERGIES']
    symp_list = ['SYMPTOM1', 'SYMPTOM2','SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']
    lookup_dict = {}
    SYMPTOM = []
    
    for dataset in datasets:
        cols = list(dataset)
        cols.remove('VAERS_ID')
        for x in cols:
            value = []
            if (x not in text_fields) and (x != 'SYMPTOM_TEXT'):
                value = dataset[x].dropna().unique().tolist()
                lookup_dict[x] = value
            if x in symp_list:
                temp = dataset[x].dropna().unique().tolist()
                SYMPTOM += temp 
        SYMPTOM = list(set(SYMPTOM))
    lookup_dict['SYMPTOM'] = SYMPTOM
    lookup_dict['SYMPTOM_TXT'] = SYMPTOM
    lookup_dict['PRIOR_VAX'] = vax_name(lookup_dict['VAX_NAME'])
    return lookup_dict

# %%
lookup2021 = build_lookup(data='./VAERS22/2022VAERSDATA.csv', vax='./VAERS22/2022VAERSVAX.csv', symp='./VAERS22/2022VAERSSYMPTOMS.csv')
# Out:
# C:\Users\eyang\AppData\Local\Temp\ipykernel_44956\92007711.py:4: DtypeWarning: Columns (7,12,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f, encoding = 'Windows-1252')

# %%
fout = open("lookup2022.json", "w")
json.dump(lookup2021, fout)
fout.close()

# %% [markdown]
# # Populate Questions & BIO Tagging

# %%
df_lt = pd.read_excel("./Template/Template-Easy-Text2ESQ.xlsx")

# %%
f = open('./VAERS22/lookup2022.json',) 
lookup = json.load(f)

# %%
def find_key(tokens, pattern):
    key_idx = []
    for idx, x in enumerate(tokens):
        token_key = re.findall(pattern, x)
        if token_key != []:
            key_idx.append((token_key[0], idx))
    return key_idx

def BIO_tagging(question, values_tmpl, keys_tmpl, token_tmpl):
    
    BIO = []
    token_question = word_tokenize(question)
    v_len = [len(word_tokenize(str(x))) for x in values_tmpl]
    BIO = ['O' for x in range(keys_tmpl[0][1])]
    for idx, l in enumerate(v_len):
        for x in range(l):
            if x == 0:
                beginning = 'B-{0}'.format(keys_tmpl[idx][0])
                BIO.append(beginning)
            else: 
                inside = 'I-{0}'.format(keys_tmpl[idx][0])
                BIO.append(inside)
        try:
            ph_idx_diff = keys_tmpl[idx+1][1] - keys_tmpl[idx][1]
            if ph_idx_diff > 1:
                for x in range(ph_idx_diff -1):
                    BIO.append("O")
        except:
            sen_idx_diff = len(token_tmpl) - 1 - keys_tmpl[idx][1]
            if sen_idx_diff > 0:
                for x in range(sen_idx_diff):
                    BIO.append("O")
                    
    output = []
    for x in list(zip(token_question, BIO)):
        temp_dict = {'text': x[0], 'label':x[1]}
        output.append(temp_dict)
            
    return output


def sub_BIO(q, lookup_table):
    pattern = re.compile(r'\[(.*?)\]', re.S)
    questions= []
    tokens = []
    
    tokenizer = RegexpTokenizer('\w+|\[\w+\]|\S+')
    token_tmpl = tokenizer.tokenize(q)
    keys_tmpl = find_key(token_tmpl, pattern) #[(placeholder1, idx1), (placeholder2, idx2)]
    
    if len(keys_tmpl) == 1:
        for v in randsample(lookup_table[keys_tmpl[0][0]]):
            values_tmpl = [v]
            question = re.sub(r"\[(.*?)\]", lambda x: str(v), q)
            questions.append(question)
            token_bio = BIO_tagging(question, values_tmpl, keys_tmpl, token_tmpl)
            tokens.append(token_bio)
            
    elif len(keys_tmpl) == 2:
        for v, vs in zip(randsample(lookup_table[keys_tmpl[0][0]]), randsample(lookup_table[keys_tmpl[1][0]])):
            values_tmpl = [v, vs]
            question = re.sub(r"\[(.*?)\]", lambda x: str(v), q, count=1)
            question = re.sub(r"\[(.*?)\]", lambda x: str(vs), question)
            questions.append(question)
            token_bio = BIO_tagging(question, values_tmpl, keys_tmpl, token_tmpl)
            tokens.append(token_bio)
    
    # Need to add BIO tagging manually for questions that don't have a key/placeholder.
    # Will update this part later

    output = {'Questions':questions, 'BIO_tagging':tokens}
            
    return output

# %%
def randsample(lookup_list):
    # random sample the lookup table value based on the total number of value in one field 
#     if len(lookup_list) <= 100:
#         value_list = lookup_list
#     elif len(lookup_list) > 100 and len(lookup_list) <= 300 :
#         value_list = sample(lookup_list, 100)
#     elif len(lookup_list) > 300:
#         value_list = sample(lookup_list, 150)
#     return value_list
    return lookup_list

def create_id(question, query, index):
    
    # generate id with a format of "Question template id" + "Query template id" + "Index"
    # example: "01100001" 
    # the first two digits "01" indicates the question template id 1
    # the third digit "1" indicates the query template id 1
    # the last five digits "00001" indicates the index of the question 1
    
    question = str(question)
    query = str(query)
    index = str(index)
    
    if len(question) == 1:
        question = '0' + question
    
    diff = 5 - len(index)
    if diff < 5:
        index = '0'*diff + index
    
    output = question + query + index
    
    return output


def populate_questions(dataset, lookup_table):
    df = dataset.copy()
    df['Question Template'] = df['Question Template'].apply(lambda x: x.split("##"))
    df = df.explode('Question Template').reset_index().drop(columns='index')
    df = df[df['Difficulty'] == 'Easy']
    
    df['output'] = df['Question Template'].apply(lambda x: sub_BIO(x, lookup_table))
    df['Questions'] = df.output.apply(lambda x: x['Questions'])
    df['Tokens'] = df.output.apply(lambda x: x['BIO_tagging'])
    df = df.drop(columns='output')
    
    df = df.apply(lambda x: x.explode()).reset_index()

    df['index'] = df.index.values
    df['Query Template ID'] = df['Query Template ID'].apply(lambda x: int(x))
    df['id'] = list(map(lambda x, y, z: create_id(x, y, z), \
                        df['Question Template ID'], \
                        df['Query Template ID'], \
                        df['index']))
    df = df.drop(columns='index')

    return df

# %%
df = populate_questions(df_lt, lookup)

# %%
df
# Out:
#         Question Template ID      Data File                      Field   \
# 0                          1      VAERSDATA                    RECVDATE
# 1                          1      VAERSDATA                    RECVDATE
# 2                          1      VAERSDATA                    RECVDATE
# 3                          1      VAERSDATA                    RECVDATE
# 4                          1      VAERSDATA                    RECVDATE
# ...                      ...            ...                         ...
# 272854                    50  VAERSSYMPTOMS  SYMPTOM1，SYMPTOM2，SYMPTOM3
# 272855                    50  VAERSSYMPTOMS  SYMPTOM1，SYMPTOM2，SYMPTOM3
# 272856                    50  VAERSSYMPTOMS  SYMPTOM1，SYMPTOM2，SYMPTOM3
# 272857                    50  VAERSSYMPTOMS  SYMPTOM1，SYMPTOM2，SYMPTOM3
# 272858                    50  VAERSSYMPTOMS  SYMPTOM1，SYMPTOM2，SYMPTOM3
#
#                                         Question Template  Query Template ID  \
# 0       Give me all the patients whose information are...                  1
# 1       Give me all the patients whose information are...                  1
# 2       Give me all the patients whose information are...                  1
# 3       Give me all the patients whose information are...                  1
# 4       Give me all the patients whose information are...                  1
# ...                                                   ...                ...
# 272854   which  [SYMPTOM] is the most common after vac...                  3
# 272855   which  [SYMPTOM] is the most common after vac...                  3
# 272856   which  [SYMPTOM] is the most common after vac...                  3
# 272857   which  [SYMPTOM] is the most common after vac...                  3
# 272858   which  [SYMPTOM] is the most common after vac...                  3
#
#        Difficulty                                          Questions  \
# 0            Easy  Give me all the patients whose information are...
# 1            Easy  Give me all the patients whose information are...
# 2            Easy  Give me all the patients whose information are...
# 3            Easy  Give me all the patients whose information are...
# 4            Easy  Give me all the patients whose information are...
# ...           ...                                                ...
# 272854       Easy   which  Liver transplant rejection is the most...
# 272855       Easy   which  Device loosening is the most common af...
# 272856       Easy   which  Myasthenic syndrome is the most common...
# 272857       Easy   which  Compartment pressure test is the most ...
# 272858       Easy   which  Intrinsic factor antibody positive is ...
#
#                                                    Tokens         id
# 0       [{'text': 'Give', 'label': 'O'}, {'text': 'me'...   01100000
# 1       [{'text': 'Give', 'label': 'O'}, {'text': 'me'...   01100001
# 2       [{'text': 'Give', 'label': 'O'}, {'text': 'me'...   01100002
# 3       [{'text': 'Give', 'label': 'O'}, {'text': 'me'...   01100003
# 4       [{'text': 'Give', 'label': 'O'}, {'text': 'me'...   01100004
# ...                                                   ...        ...
# 272854  [{'text': 'which', 'label': 'O'}, {'text': 'Li...  503272854
# 272855  [{'text': 'which', 'label': 'O'}, {'text': 'De...  503272855
# 272856  [{'text': 'which', 'label': 'O'}, {'text': 'My...  503272856
# 272857  [{'text': 'which', 'label': 'O'}, {'text': 'Co...  503272857
# 272858  [{'text': 'which', 'label': 'O'}, {'text': 'In...  503272858
#
# [272859 rows x 9 columns]

# %%
questions = df.set_index(['id'])['Questions'].to_dict()

# %%
questions
# Out:
# {'01100000': 'Give me all the patients whose information are received on 03/26/2022. ',
#  '01100001': 'Give me all the patients whose information are received on 01/11/2022. ',
#  '01100002': 'Give me all the patients whose information are received on 02/17/2022. ',
#  '01100003': 'Give me all the patients whose information are received on 03/31/2022. ',
#  '01100004': 'Give me all the patients whose information are received on 04/17/2022. ',
#  '01100005': 'Give me all the patients whose information are received on 03/24/2022. ',
#  '01100006': 'Give me all the patients whose information are received on 02/06/2022. ',
#  '01100007': 'Give me all the patients whose information are received on 03/04/2022. ',
#  '01100008': 'Give me all the patients whose information are received on 05/27/2022. ',
#  '01100009': 'Give me all the patients whose information are received on 04/01/2022. ',
#  '01100010': 'Give me all the patients whose information are received on 04/08/2022. ',
#  '01100011': 'Give me all the patients whose information are received on 01/18/2022. ',
#  '01100012': 'Give me all the patients whose information are received on 05/08/2022. ',
#  '01100013': 'Give me all the patients whose information are received on 01/20/2022. ',
#  '01100014': 'Give me all the patients whose information are received on 05/21/2022. ',
#  '01100015': 'Give me all the patients whose information are received on 04/14/2022. ',
#  '01100016': 'Give me all the patients whose information are received on 03/19/2022. ',
#  '01100017': 'Give me all the patients whose information are received on 05/10/2022. ',
#  '01100018': 'Give me all the patients whose information are received on 03/16/2022. ',
#  '01100019': 'Give me all the patients whose information are received on 03/27/2022. ',
#  '01100020': 'Give me all the patients whose information are received on 02/05/2022. ',
#  '01100021': 'Give me all the patients whose information are received on 05/14/2022. ',
#  '01100022': 'Give me all the patients whose information are received on 02/10/2022. ',
#  '01100023': 'Give me all the patients whose information are received on 03/23/2022. ',
#  '01100024': 'Give me all the patients whose information are received on 01/25/2022. ',
#  '01100025': 'Give me all the patients whose information are received on 01/22/2022. ',
#  '01100026': 'Give me all the patients whose information are received on 01/12/2022. ',
#  '01100027': 'Give me all the patients whose information are received on 05/03/2022. ',
#  '01100028': 'Give me all the patients whose information are received on 04/11/2022. ',
#  '01100029': 'Give me all the patients whose information are received on 04/15/2022. ',
#  '01100030': 'Give me all the patients whose information are received on 02/20/2022. ',
#  '01100031': 'Give me all the patients whose information are received on 04/10/2022. ',
#  '01100032': 'Give me all the patients whose information are received on 04/13/2022. ',
#  '01100033': 'Give me all the patients whose information are received on 02/21/2022. ',
#  '01100034': 'Give me all the patients whose information are received on 01/02/2022. ',
#  '01100035': 'Give me all the patients whose information are received on 03/09/2022. ',
#  '01100036': 'Give me all the patients whose information are received on 03/30/2022. ',
#  '01100037': 'Give me all the patients whose information are received on 02/27/2022. ',
#  '01100038': 'Give me all the patients whose information are received on 01/03/2022. ',
#  '01100363': " How many patients' record are received on 02/19/2022 ",
#  '01100364': " How many patients' record are received on 05/08/2022 ",
#  '01100365': " How many patients' record are received on 04/02/2022 ",
#  '01100366': " How many patients' record are received on 02/16/2022 ",
#  '01100367': " How many patients' record are received on 04/04/2022 ",
#  '01100368': " How many patients' record are received on 05/14/2022 ",
#  '01100369': " How many patients' record are received on 05/11/2022 ",
#  '01100370': " How many patients' record are received on 03/26/2022 ",
#  '01100371': " How many patients' record are received on 05/23/2022 ",
#  '01100372': " How many patients' record are received on 01/31/2022 ",
#  '01100373': " How many patients' record are received on 03/04/2022 ",
#  '01100374': " How many patients' record are received on 02/17/2022 ",
#  '01100375': " How many patients' record are received on 04/07/2022 ",
#  '01100376': " How many patients' record are received on 05/15/2022 ",
#  '01100377': " How many patients' record are received on 01/05/2022 ",
#  '01100378': " How many patients' record are received on 05/06/2022 ",
#  '01100379': " How many patients' record are received on 01/29/2022 ",
#  '01100380': " How many patients' record are received on 01/26/2022 ",
#  '01100381': " How many patients' record are received on 01/17/2022 ",
#  '01100382': " How many patients' record are received on 03/31/2022 ",
#  '01100383': " How many patients' record are received on 03/23/2022 ",
#  '01100384': " How many patients' record are received on 01/24/2022 ",
#  '01100385': " How many patients' record are received on 01/07/2022 ",
#  '01100386': " How many patients' record are received on 01/19/2022 ",
#  '01100387': " How many patients' record are received on 03/09/2022 ",
#  '01100388': " How many patients' record are received on 04/28/2022 ",
#  '01100389': " How many patients' record are received on 01/08/2022 ",
#  '01100390': " How many patients' record are received on 05/17/2022 ",
#  '01100391': " How many patients' record are received on 01/15/2022 ",
#  '01100392': " How many patients' record are received on 01/03/2022 ",
#  '01100393': " How many patients' record are received on 03/19/2022 ",
#  '01100394': " How many patients' record are received on 05/26/2022 ",
#  '01100395': " How many patients' record are received on 05/24/2022 ",
#  '01100396': " How many patients' record are received on 04/01/2022 ",
#  '01100397': " How many patients' record are received on 01/21/2022 ",
#  '01100398': " How many patients' record are received on 02/11/2022 ",
#  '01100399': " How many patients' record are received on 04/14/2022 ",
#  '01100400': ' Find the day 01/04/2022 when the most people choose to submit records.',
#  '01100401': ' Find the day 04/20/2022 when the most people choose to submit records.',
#  '01100402': ' Find the day 04/09/2022 when the most people choose to submit records.',
#  '01100403': ' Find the day 01/08/2022 when the most people choose to submit records.',
#  '01100404': ' Find the day 01/14/2022 when the most people choose to submit records.',
#  '01100405': ' Find the day 02/25/2022 when the most people choose to submit records.',
#  '01100406': ' Find the day 02/16/2022 when the most people choose to submit records.',
#  '01100407': ' Find the day 03/26/2022 when the most people choose to submit records.',
#  '01100408': ' Find the day 01/29/2022 when the most people choose to submit records.',
#  '01100409': ' Find the day 05/07/2022 when the most people choose to submit records.',
#  '01100410': ' Find the day 05/19/2022 when the most people choose to submit records.',
#  '01100411': ' Find the day 01/15/2022 when the most people choose to submit records.',
#  '01100412': ' Find the day 05/11/2022 when the most people choose to submit records.',
#  '01100413': ' Find the day 01/31/2022 when the most people choose to submit records.',
#  '01100414': ' Find the day 05/13/2022 when the most people choose to submit records.',
#  '01100415': ' Find the day 03/15/2022 when the most people choose to submit records.',
#  '01100416': ' Find the day 01/01/2022 when the most people choose to submit records.',
#  '01100417': ' Find the day 01/23/2022 when the most people choose to submit records.',
#  '01100418': ' Find the day 02/10/2022 when the most people choose to submit records.',
#  '01100419': ' Find the day 03/05/2022 when the most people choose to submit records.',
#  '01100420': ' Find the day 02/09/2022 when the most people choose to submit records.',
#  '01100421': ' Find the day 01/03/2022 when the most people choose to submit records.',
#  '01100422': ' Find the day 03/11/2022 when the most people choose to submit records.',
#  '01100423': ' Find the day 05/25/2022 when the most people choose to submit records.',
#  '01100424': ' Find the day 02/06/2022 when the most people choose to submit records.',
#  '01100425': ' Find the day 04/23/2022 when the most people choose to submit records.',
#  '01100426': ' Find the day 01/28/2022 when the most people choose to submit records.',
#  '01100427': ' Find the day 02/04/2022 when the most people choose to submit records.',
#  '01100428': ' Find the day 05/15/2022 when the most people choose to submit records.',
#  '01100429': ' Find the day 02/08/2022 when the most people choose to submit records.',
#  '01100430': ' Find the day 03/10/2022 when the most people choose to submit records.',
#  '01100431': ' Find the day 03/06/2022 when the most people choose to submit records.',
#  '01100432': ' Find the day 02/12/2022 when the most people choose to submit records.',
#  '01100433': ' Find the day 04/26/2022 when the most people choose to submit records.',
#  '01100434': ' Find the day 02/05/2022 when the most people choose to submit records.',
#  '01100435': ' Find the day 02/13/2022 when the most people choose to submit records.',
#  '01100436': ' Find the day 03/28/2022 when the most people choose to submit records.',
#  '01100437': ' Find the day 02/17/2022 when the most people choose to submit records.',
#  '01100438': ' Find the day 03/17/2022 when the most people choose to submit records.',
#  '01100439': ' Find the day 01/12/2022 when the most people choose to submit records.',
#  '01100440': ' Find the day 03/16/2022 when the most people choose to submit records.',
#  '01100441': ' Find the day 04/07/2022 when the most people choose to submit records.',
#  '01100442': ' Find the day 04/18/2022 when the most people choose to submit records.',
#  '01100443': ' Find the day 05/05/2022 when the most people choose to submit records.',
#  '01100444': ' Find the day 04/10/2022 when the most people choose to submit records.',
#  '01100445': ' Find the day 04/14/2022 when the most people choose to submit records.',
#  '01100446': ' Find the day 03/08/2022 when the most people choose to submit records.',
#  '01100447': ' Find the day 05/12/2022 when the most people choose to submit records.',
#  '01100448': ' Find the day 02/15/2022 when the most people choose to submit records.',
#  '01100449': ' Find the day 01/19/2022 when the most people choose to submit records.',
#  '01100450': ' Find the day 03/13/2022 when the most people choose to submit records.',
#  '01100451': ' Find the day 02/26/2022 when the most people choose to submit records.',
#  '01100452': ' Find the day 01/27/2022 when the most people choose to submit records.',
#  '01100453': ' Find the day 01/09/2022 when the most people choose to submit records.',
#  '01100454': ' Find the day 05/08/2022 when the most people choose to submit records.',
#  '01100455': ' Find the day 03/27/2022 when the most people choose to submit records.',
#  '01100456': ' Find the day 02/18/2022 when the most people choose to submit records.',
#  '01100457': ' Find the day 04/15/2022 when the most people choose to submit records.',
#  '01100458': ' Find the day 04/28/2022 when the most people choose to submit records.',
#  '01100459': ' Find the day 04/11/2022 when the most people choose to submit records.',
#  '01100460': ' Find the day 03/25/2022 when the most people choose to submit records.',
#  '01100461': ' Find the day 01/18/2022 when the most people choose to submit records.',
#  '01100462': ' Find the day 03/29/2022 when the most people choose to submit records.',
#  '01100463': ' Find the day 04/04/2022 when the most people choose to submit records.',
#  '01100464': ' Find the day 01/30/2022 when the most people choose to submit records.',
#  '01100465': ' Find the day 04/25/2022 when the most people choose to submit records.',
#  '01100466': ' Find the day 02/02/2022 when the most people choose to submit records.',
#  '01100467': ' Find the day 01/25/2022 when the most people choose to submit records.',
#  '01100468': ' Find the day 01/24/2022 when the most people choose to submit records.',
#  '01100469': ' Find the day 04/17/2022 when the most people choose to submit records.',
#  '01100470': ' Find the day 01/06/2022 when the most people choose to submit records.',
#  '01100471': ' Find the day 02/23/2022 when the most people choose to submit records.',
#  '01100472': ' Find the day 01/16/2022 when the most people choose to submit records.',
#  '01100473': ' Find the day 02/28/2022 when the most people choose to submit records.',
#  '01100474': ' Find the day 03/23/2022 when the most people choose to submit records.',
#  '01100475': ' Find the day 02/24/2022 when the most people choose to submit records.',
#  '01100476': ' Find the day 03/21/2022 when the most people choose to submit records.',
#  '01100477': ' Find the day 03/12/2022 when the most people choose to submit records.',
#  '01100478': ' Find the day 03/22/2022 when the most people choose to submit records.',
#  '01100479': ' Find the day 05/26/2022 when the most people choose to submit records.',
#  '01100480': ' Find the day 05/24/2022 when the most people choose to submit records.',
#  '01100481': ' Find the day 01/13/2022 when the most people choose to submit records.',
#  '01100482': ' Find the day 02/14/2022 when the most people choose to submit records.',
#  '01100483': ' Find the day 03/03/2022 when the most people choose to submit records.',
#  '01100484': ' Find the day 04/05/2022 when the most people choose to submit records.',
#  '01100485': ' Find the day 03/18/2022 when the most people choose to submit records.',
#  '01100486': ' Find the day 01/07/2022 when the most people choose to submit records.',
#  '01100487': ' Find the day 03/14/2022 when the most people choose to submit records.',
#  '01100488': ' Find the day 05/16/2022 when the most people choose to submit records.',
#  '01100489': ' Find the day 04/03/2022 when the most people choose to submit records.',
#  '01100490': ' Find the day 05/23/2022 when the most people choose to submit records.',
#  '01100491': ' Find the day 03/19/2022 when the most people choose to submit records.',
#  '01100492': ' Find the day 05/06/2022 when the most people choose to submit records.',
#  '01100493': ' Find the day 04/16/2022 when the most people choose to submit records.',
#  '01100494': ' Find the day 02/20/2022 when the most people choose to submit records.',
#  '01100495': ' Find the day 02/27/2022 when the most people choose to submit records.',
#  '01100496': ' Find the day 04/06/2022 when the most people choose to submit records.',
#  '01100497': ' Find the day 05/09/2022 when the most people choose to submit records.',
#  '01100498': ' Find the day 01/21/2022 when the most people choose to submit records.',
#  '01100499': ' Find the day 03/04/2022 when the most people choose to submit records.',
#  '02200500': 'Give me all the patients who is from CA. ',
#  '02200501': 'Give me all the patients who is from OH. ',
#  '02200502': 'Give me all the patients who is from MS. ',
#  '02200503': 'Give me all the patients who is from CT. ',
#  '02200504': 'Give me all the patients who is from DE. ',
#  '02200505': 'Give me all the patients who is from ME. ',
#  '02200506': 'Give me all the patients who is from NY. ',
#  '02200507': 'Give me all the patients who is from VA. ',
#  '02200508': 'Give me all the patients who is from IL. ',
#  '02200509': 'Give me all the patients who is from NJ. ',
#  '02200510': 'Give me all the patients who is from NE. ',
#  '02200511': 'Give me all the patients who is from TX. ',
#  '02200512': 'Give me all the patients who is from HI. ',
#  '02200513': 'Give me all the patients who is from PA. ',
#  '02200514': 'Give me all the patients who is from MA. ',
#  '02200515': 'Give me all the patients who is from MI. ',
#  '02200516': 'Give me all the patients who is from GA. ',
#  '02200517': 'Give me all the patients who is from NH. ',
#  '02200518': 'Give me all the patients who is from MO. ',
#  '02200519': 'Give me all the patients who is from UT. ',
#  '02200520': 'Give me all the patients who is from FL. ',
#  '02200521': 'Give me all the patients who is from MD. ',
#  '02200522': 'Give me all the patients who is from WA. ',
#  '02200523': 'Give me all the patients who is from NC. ',
#  '02200524': 'Give me all the patients who is from KS. ',
#  '02200525': 'Give me all the patients who is from CO. ',
#  '02200526': 'Give me all the patients who is from MT. ',
#  '02200527': 'Give me all the patients who is from IA. ',
#  '02200528': 'Give me all the patients who is from MN. ',
#  '02200529': 'Give me all the patients who is from SC. ',
#  '02200530': 'Give me all the patients who is from KY. ',
#  '02200531': 'Give me all the patients who is from RI. ',
#  '02200532': 'Give me all the patients who is from ID. ',
#  '02200533': 'Give me all the patients who is from AZ. ',
#  '02200534': 'Give me all the patients who is from AL. ',
#  '02200535': 'Give me all the patients who is from TN. ',
#  '02200536': 'Give me all the patients who is from IN. ',
#  '02200537': 'Give me all the patients who is from WI. ',
#  '02200538': 'Give me all the patients who is from OR. ',
#  '02200539': 'Give me all the patients who is from LA. ',
#  '02200540': 'Give me all the patients who is from DC. ',
#  '02200541': 'Give me all the patients who is from NV. ',
#  '02200542': 'Give me all the patients who is from NM. ',
#  '02200543': 'Give me all the patients who is from VI. ',
#  '02200544': 'Give me all the patients who is from SD. ',
#  '02200545': 'Give me all the patients who is from PR. ',
#  '02200546': 'Give me all the patients who is from WV. ',
#  '02200547': 'Give me all the patients who is from VT. ',
#  '02200548': 'Give me all the patients who is from ND. ',
#  '02200549': 'Give me all the patients who is from AR. ',
#  '02200550': 'Give me all the patients who is from OK. ',
#  '02200551': 'Give me all the patients who is from GU. ',
#  '02200552': 'Give me all the patients who is from AK. ',
#  '02200553': 'Give me all the patients who is from WY. ',
#  '02200554': 'Give me all the patients who is from MP. ',
#  '02200555': 'Give me all the patients who is from AS. ',
#  '02200556': 'Give me all the patients who is from MH. ',
#  '02200557': 'Give me all the patients who is from PW. ',
#  '02200558': 'Give me all the patients who is from QW. ',
#  '02200559': ' Give me all the patients who comes from CA. ',
#  '02200560': ' Give me all the patients who comes from OH. ',
#  '02200561': ' Give me all the patients who comes from MS. ',
#  '02200562': ' Give me all the patients who comes from CT. ',
#  '02200563': ' Give me all the patients who comes from DE. ',
#  '02200564': ' Give me all the patients who comes from ME. ',
#  '02200565': ' Give me all the patients who comes from NY. ',
#  '02200566': ' Give me all the patients who comes from VA. ',
#  '02200567': ' Give me all the patients who comes from IL. ',
#  '02200568': ' Give me all the patients who comes from NJ. ',
#  '02200569': ' Give me all the patients who comes from NE. ',
#  '02200570': ' Give me all the patients who comes from TX. ',
#  '02200571': ' Give me all the patients who comes from HI. ',
#  '02200572': ' Give me all the patients who comes from PA. ',
#  '02200573': ' Give me all the patients who comes from MA. ',
#  '02200574': ' Give me all the patients who comes from MI. ',
#  '02200575': ' Give me all the patients who comes from GA. ',
#  '02200576': ' Give me all the patients who comes from NH. ',
#  '02200577': ' Give me all the patients who comes from MO. ',
#  '02200578': ' Give me all the patients who comes from UT. ',
#  '02200579': ' Give me all the patients who comes from FL. ',
#  '02200580': ' Give me all the patients who comes from MD. ',
#  '02200581': ' Give me all the patients who comes from WA. ',
#  '02200582': ' Give me all the patients who comes from NC. ',
#  '02200583': ' Give me all the patients who comes from KS. ',
#  '02200584': ' Give me all the patients who comes from CO. ',
#  '02200585': ' Give me all the patients who comes from MT. ',
#  '02200586': ' Give me all the patients who comes from IA. ',
#  '02200587': ' Give me all the patients who comes from MN. ',
#  '02200588': ' Give me all the patients who comes from SC. ',
#  '02200589': ' Give me all the patients who comes from KY. ',
#  '02200590': ' Give me all the patients who comes from RI. ',
#  '02200591': ' Give me all the patients who comes from ID. ',
#  '02200592': ' Give me all the patients who comes from AZ. ',
#  '02200593': ' Give me all the patients who comes from AL. ',
#  '02200594': ' Give me all the patients who comes from TN. ',
#  '02200595': ' Give me all the patients who comes from IN. ',
#  '02200596': ' Give me all the patients who comes from WI. ',
#  '02200597': ' Give me all the patients who comes from OR. ',
#  '02200598': ' Give me all the patients who comes from LA. ',
#  '02200599': ' Give me all the patients who comes from DC. ',
#  '02200600': ' Give me all the patients who comes from NV. ',
#  '02200601': ' Give me all the patients who comes from NM. ',
#  '02200602': ' Give me all the patients who comes from VI. ',
#  '02200603': ' Give me all the patients who comes from SD. ',
#  '02200604': ' Give me all the patients who comes from PR. ',
#  '02200605': ' Give me all the patients who comes from WV. ',
#  '02200606': ' Give me all the patients who comes from VT. ',
#  '02200607': ' Give me all the patients who comes from ND. ',
#  '02200608': ' Give me all the patients who comes from AR. ',
#  '02200609': ' Give me all the patients who comes from OK. ',
#  '02200610': ' Give me all the patients who comes from GU. ',
#  '02200611': ' Give me all the patients who comes from AK. ',
#  '02200612': ' Give me all the patients who comes from WY. ',
#  '02200613': ' Give me all the patients who comes from MP. ',
#  '02200614': ' Give me all the patients who comes from AS. ',
#  '02200615': ' Give me all the patients who comes from MH. ',
#  '02200616': ' Give me all the patients who comes from PW. ',
#  '02200617': ' Give me all the patients who comes from QW. ',
#  '02200618': ' Find all the records that the home state is CA. ',
#  '02200619': ' Find all the records that the home state is OH. ',
#  '02200620': ' Find all the records that the home state is MS. ',
#  '02200621': ' Find all the records that the home state is CT. ',
#  '02200622': ' Find all the records that the home state is DE. ',
#  '02200623': ' Find all the records that the home state is ME. ',
#  '02200624': ' Find all the records that the home state is NY. ',
#  '02200625': ' Find all the records that the home state is VA. ',
#  '02200626': ' Find all the records that the home state is IL. ',
#  '02200627': ' Find all the records that the home state is NJ. ',
#  '02200628': ' Find all the records that the home state is NE. ',
#  '02200629': ' Find all the records that the home state is TX. ',
#  '02200630': ' Find all the records that the home state is HI. ',
#  '02200631': ' Find all the records that the home state is PA. ',
#  '02200632': ' Find all the records that the home state is MA. ',
#  '02200633': ' Find all the records that the home state is MI. ',
#  '02200634': ' Find all the records that the home state is GA. ',
#  '02200635': ' Find all the records that the home state is NH. ',
#  '02200636': ' Find all the records that the home state is MO. ',
#  '02200637': ' Find all the records that the home state is UT. ',
#  '02200638': ' Find all the records that the home state is FL. ',
#  '02200639': ' Find all the records that the home state is MD. ',
#  '02200640': ' Find all the records that the home state is WA. ',
#  '02200641': ' Find all the records that the home state is NC. ',
#  '02200642': ' Find all the records that the home state is KS. ',
#  '02200643': ' Find all the records that the home state is CO. ',
#  '02200644': ' Find all the records that the home state is MT. ',
#  '02200645': ' Find all the records that the home state is IA. ',
#  '02200646': ' Find all the records that the home state is MN. ',
#  '02200647': ' Find all the records that the home state is SC. ',
#  '02200648': ' Find all the records that the home state is KY. ',
#  '02200649': ' Find all the records that the home state is RI. ',
#  '02200650': ' Find all the records that the home state is ID. ',
#  '02200651': ' Find all the records that the home state is AZ. ',
#  '02200652': ' Find all the records that the home state is AL. ',
#  '02200653': ' Find all the records that the home state is TN. ',
#  '02200654': ' Find all the records that the home state is IN. ',
#  '02200655': ' Find all the records that the home state is WI. ',
#  '02200656': ' Find all the records that the home state is OR. ',
#  '02200657': ' Find all the records that the home state is LA. ',
#  '02200658': ' Find all the records that the home state is DC. ',
#  '02200659': ' Find all the records that the home state is NV. ',
#  '02200660': ' Find all the records that the home state is NM. ',
#  '02200661': ' Find all the records that the home state is VI. ',
#  '02200662': ' Find all the records that the home state is SD. ',
#  '02200663': ' Find all the records that the home state is PR. ',
#  '02200664': ' Find all the records that the home state is WV. ',
#  '02200665': ' Find all the records that the home state is VT. ',
#  '02200666': ' Find all the records that the home state is ND. ',
#  '02200667': ' Find all the records that the home state is AR. ',
#  '02200668': ' Find all the records that the home state is OK. ',
#  '02200669': ' Find all the records that the home state is GU. ',
#  '02200670': ' Find all the records that the home state is AK. ',
#  '02200671': ' Find all the records that the home state is WY. ',
#  '02200672': ' Find all the records that the home state is MP. ',
#  '02200673': ' Find all the records that the home state is AS. ',
#  '02200674': ' Find all the records that the home state is MH. ',
#  '02200675': ' Find all the records that the home state is PW. ',
#  '02200676': ' Find all the records that the home state is QW. ',
# ...
#  '02200759': ' Give me the NC which has the most numbers of records',
#  '02200760': ' Give me the KS which has the most numbers of records',
#  '02200761': ' Give me the CO which has the most numbers of records',
#  '02200762': ' Give me the MT which has the most numbers of records',
#  '02200763': ' Give me the IA which has the most numbers of records',
#  '02200764': ' Give me the MN which has the most numbers of records',
#  '02200765': ' Give me the SC which has the most numbers of records',
#  '02200766': ' Give me the KY which has the most numbers of records',
#  '02200767': ' Give me the RI which has the most numbers of records',
#  '02200768': ' Give me the ID which has the most numbers of records',
#  '02200769': ' Give me the AZ which has the most numbers of records',
#  '02200770': ' Give me the AL which has the most numbers of records',
#  '02200771': ' Give me the TN which has the most numbers of records',
#  '02200772': ' Give me the IN which has the most numbers of records',
#  '02200773': ' Give me the WI which has the most numbers of records',
#  '02200774': ' Give me the OR which has the most numbers of records',
#  '02200775': ' Give me the LA which has the most numbers of records',
#  '02200776': ' Give me the DC which has the most numbers of records',
#  '02200777': ' Give me the NV which has the most numbers of records',
#  '02200778': ' Give me the NM which has the most numbers of records',
#  '02200779': ' Give me the VI which has the most numbers of records',
#  '02200780': ' Give me the SD which has the most numbers of records',
#  '02200781': ' Give me the PR which has the most numbers of records',
#  '02200782': ' Give me the WV which has the most numbers of records',
#  '02200783': ' Give me the VT which has the most numbers of records',
#  '02200784': ' Give me the ND which has the most numbers of records',
#  '02200785': ' Give me the AR which has the most numbers of records',
#  '02200786': ' Give me the OK which has the most numbers of records',
#  '02200787': ' Give me the GU which has the most numbers of records',
#  '02200788': ' Give me the AK which has the most numbers of records',
#  '02200789': ' Give me the WY which has the most numbers of records',
#  '02200790': ' Give me the MP which has the most numbers of records',
#  '02200791': ' Give me the AS which has the most numbers of records',
#  '02200792': ' Give me the MH which has the most numbers of records',
#  '02200793': ' Give me the PW which has the most numbers of records',
#  '02200794': ' Give me the QW which has the most numbers of records',
#  '03200795': 'Give me all the patients who is 87.0 years old. ',
#  '03200796': 'Give me all the patients who is 15.0 years old. ',
#  '03200797': 'Give me all the patients who is 5.83 years old. ',
#  '03200798': 'Give me all the patients who is 90.0 years old. ',
#  '03200799': 'Give me all the patients who is 17.0 years old. ',
#  '03200800': 'Give me all the patients who is 60.0 years old. ',
#  '03200801': 'Give me all the patients who is 96.0 years old. ',
#  '03200802': 'Give me all the patients who is 51.0 years old. ',
#  '03200803': 'Give me all the patients who is 50.0 years old. ',
#  '03200804': 'Give me all the patients who is 0.5 years old. ',
#  '03200805': 'Give me all the patients who is 1.92 years old. ',
#  '03200806': 'Give me all the patients who is 31.0 years old. ',
#  '03200807': 'Give me all the patients who is 71.0 years old. ',
#  '03200808': 'Give me all the patients who is 65.0 years old. ',
#  '03200809': 'Give me all the patients who is 117.0 years old. ',
#  '03200810': 'Give me all the patients who is 16.0 years old. ',
#  '03200811': 'Give me all the patients who is 46.0 years old. ',
#  '03200812': 'Give me all the patients who is 2.33 years old. ',
#  '03200813': 'Give me all the patients who is 61.0 years old. ',
#  '03200814': 'Give me all the patients who is 1.58 years old. ',
#  '03200815': 'Give me all the patients who is 33.0 years old. ',
#  '03200816': 'Give me all the patients who is 0.58 years old. ',
#  '03200817': 'Give me all the patients who is 0.67 years old. ',
#  '03200818': 'Give me all the patients who is 59.0 years old. ',
#  '03200819': 'Give me all the patients who is 1.75 years old. ',
#  '03200820': 'Give me all the patients who is 35.0 years old. ',
#  '03200821': 'Give me all the patients who is 47.0 years old. ',
#  '03200822': 'Give me all the patients who is 36.0 years old. ',
#  '03200823': 'Give me all the patients who is 12.0 years old. ',
#  '03200824': 'Give me all the patients who is 40.0 years old. ',
#  '03200825': 'Give me all the patients who is 62.0 years old. ',
#  '03200826': 'Give me all the patients who is 41.0 years old. ',
#  '03200827': 'Give me all the patients who is 42.0 years old. ',
#  '03200828': 'Give me all the patients who is 84.0 years old. ',
#  '03200829': 'Give me all the patients who is 89.0 years old. ',
#  '03200830': 'Give me all the patients who is 8.0 years old. ',
#  '03200831': 'Give me all the patients who is 75.0 years old. ',
#  '03200832': 'Give me all the patients who is 0.08 years old. ',
#  '03200833': 'Give me all the patients who is 0.42 years old. ',
#  '03200834': 'Give me all the patients who is 1.08 years old. ',
#  '03200835': 'Give me all the patients who is 57.0 years old. ',
#  '03200836': 'Give me all the patients who is 102.0 years old. ',
#  '03200837': 'Give me all the patients who is 6.0 years old. ',
#  '03200838': 'Give me all the patients who is 10.0 years old. ',
#  '03200839': 'Give me all the patients who is 83.0 years old. ',
#  '03200840': 'Give me all the patients who is 30.0 years old. ',
#  '03200841': 'Give me all the patients who is 80.0 years old. ',
#  '03200842': 'Give me all the patients who is 14.0 years old. ',
#  '03200843': 'Give me all the patients who is 44.0 years old. ',
#  '03200844': 'Give me all the patients who is 11.0 years old. ',
#  '03200845': 'Give me all the patients who is 82.0 years old. ',
#  '03200846': 'Give me all the patients who is 74.0 years old. ',
#  '03200847': 'Give me all the patients who is 67.0 years old. ',
#  '03200848': 'Give me all the patients who is 69.0 years old. ',
#  '03200849': 'Give me all the patients who is 37.0 years old. ',
#  '03200850': 'Give me all the patients who is 1.17 years old. ',
#  '03200851': 'Give me all the patients who is 101.0 years old. ',
#  '03200852': 'Give me all the patients who is 88.0 years old. ',
#  '03200853': 'Give me all the patients who is 104.0 years old. ',
#  '03200854': 'Give me all the patients who is 13.0 years old. ',
#  '03200855': 'Give me all the patients who is 32.0 years old. ',
#  '03200856': 'Give me all the patients who is 66.0 years old. ',
#  '03200857': 'Give me all the patients who is 28.0 years old. ',
#  '03200858': 'Give me all the patients who is 27.0 years old. ',
#  '03200859': 'Give me all the patients who is 105.0 years old. ',
#  '03200860': 'Give me all the patients who is 0.25 years old. ',
#  '03200861': 'Give me all the patients who is 1.42 years old. ',
#  '03200862': 'Give me all the patients who is 64.0 years old. ',
#  '03200863': 'Give me all the patients who is 92.0 years old. ',
#  '03200864': 'Give me all the patients who is 25.0 years old. ',
#  '03200865': 'Give me all the patients who is 99.0 years old. ',
#  '03200866': 'Give me all the patients who is 39.0 years old. ',
#  '03200867': 'Give me all the patients who is 95.0 years old. ',
#  '03200868': 'Give me all the patients who is 21.0 years old. ',
#  '03200869': 'Give me all the patients who is 78.0 years old. ',
#  '03200870': 'Give me all the patients who is 1.67 years old. ',
#  '03200871': 'Give me all the patients who is 7.0 years old. ',
#  '03200872': 'Give me all the patients who is 26.0 years old. ',
#  '03200873': 'Give me all the patients who is 1.25 years old. ',
#  '03200874': 'Give me all the patients who is 94.0 years old. ',
#  '03200875': 'Give me all the patients who is 1.0 years old. ',
#  '03200876': 'Give me all the patients who is 72.0 years old. ',
#  '03200877': 'Give me all the patients who is 9.0 years old. ',
#  '03200878': 'Give me all the patients who is 77.0 years old. ',
#  '03200879': 'Give me all the patients who is 24.0 years old. ',
#  '03200880': 'Give me all the patients who is 100.0 years old. ',
#  '03200881': 'Give me all the patients who is 0.33 years old. ',
#  '03200882': 'Give me all the patients who is 63.0 years old. ',
#  '03200883': 'Give me all the patients who is 4.0 years old. ',
#  '03200884': 'Give me all the patients who is 49.0 years old. ',
#  '03200885': 'Give me all the patients who is 43.0 years old. ',
#  '03200886': 'Give me all the patients who is 76.0 years old. ',
#  '03200887': 'Give me all the patients who is 86.0 years old. ',
#  '03200888': 'Give me all the patients who is 68.0 years old. ',
#  '03200889': 'Give me all the patients who is 20.0 years old. ',
#  '03200890': 'Give me all the patients who is 0.92 years old. ',
#  '03200891': 'Give me all the patients who is 97.0 years old. ',
#  '03200892': 'Give me all the patients who is 19.0 years old. ',
#  '03200893': 'Give me all the patients who is 2.67 years old. ',
#  '03200894': 'Give me all the patients who is 0.75 years old. ',
#  '03200895': ' Give me all the patients who is 69.0 years old. ',
#  '03200896': ' Give me all the patients who is 53.0 years old. ',
#  '03200897': ' Give me all the patients who is 32.0 years old. ',
#  '03200898': ' Give me all the patients who is 86.0 years old. ',
#  '03200899': ' Give me all the patients who is 0.33 years old. ',
#  '03200900': ' Give me all the patients who is 0.17 years old. ',
#  '03200901': ' Give me all the patients who is 81.0 years old. ',
#  '03200902': ' Give me all the patients who is 87.0 years old. ',
#  '03200903': ' Give me all the patients who is 1.83 years old. ',
#  '03200904': ' Give me all the patients who is 19.0 years old. ',
#  '03200905': ' Give me all the patients who is 30.0 years old. ',
#  '03200906': ' Give me all the patients who is 41.0 years old. ',
#  '03200907': ' Give me all the patients who is 10.0 years old. ',
#  '03200908': ' Give me all the patients who is 28.0 years old. ',
#  '03200909': ' Give me all the patients who is 0.42 years old. ',
#  '03200910': ' Give me all the patients who is 61.0 years old. ',
#  '03200911': ' Give me all the patients who is 0.83 years old. ',
#  '03200912': ' Give me all the patients who is 62.0 years old. ',
#  '03200913': ' Give me all the patients who is 21.0 years old. ',
#  '03200914': ' Give me all the patients who is 65.0 years old. ',
#  '03200915': ' Give me all the patients who is 50.0 years old. ',
#  '03200916': ' Give me all the patients who is 1.0 years old. ',
#  '03200917': ' Give me all the patients who is 6.0 years old. ',
#  '03200918': ' Give me all the patients who is 72.0 years old. ',
#  '03200919': ' Give me all the patients who is 73.0 years old. ',
#  '03200920': ' Give me all the patients who is 9.0 years old. ',
#  '03200921': ' Give me all the patients who is 79.0 years old. ',
#  '03200922': ' Give me all the patients who is 2.08 years old. ',
#  '03200923': ' Give me all the patients who is 89.0 years old. ',
#  '03200924': ' Give me all the patients who is 105.0 years old. ',
#  '03200925': ' Give me all the patients who is 67.0 years old. ',
#  '03200926': ' Give me all the patients who is 96.0 years old. ',
#  '03200927': ' Give me all the patients who is 40.0 years old. ',
#  '03200928': ' Give me all the patients who is 78.0 years old. ',
#  '03200929': ' Give me all the patients who is 36.0 years old. ',
#  '03200930': ' Give me all the patients who is 44.0 years old. ',
#  '03200931': ' Give me all the patients who is 38.0 years old. ',
#  '03200932': ' Give me all the patients who is 34.0 years old. ',
#  '03200933': ' Give me all the patients who is 104.0 years old. ',
#  '03200988': ' Give me all the patients who is 1.58 years old. ',
#  '03200989': ' Give me all the patients who is 7.0 years old. ',
#  '03200990': ' Give me all the patients who is 46.0 years old. ',
#  '03200991': ' Give me all the patients who is 14.0 years old. ',
#  '03200992': ' Give me all the patients who is 2.33 years old. ',
#  '03200993': ' Give me all the patients who is 3.0 years old. ',
#  '03200994': ' Give me all the patients who is 83.0 years old. ',
#  '03200995': ' Return all 31.0 years old vaccine recipients. ',
#  '03200996': ' Return all 84.0 years old vaccine recipients. ',
#  '03200997': ' Return all 42.0 years old vaccine recipients. ',
#  '03200998': ' Return all 15.0 years old vaccine recipients. ',
#  '03200999': ' Return all 80.0 years old vaccine recipients. ',
#  ...}

# %% [markdown]
# ### Check query num

# %%
# save all questions an corresponding query number
query_q = []
for x in tqdm(range(len(df))):
    temp = {}
    temp['question'] = df.iloc[x]['Questions']
    temp['query'] = str(df.iloc[x]['Query Template ID'])
    query_q.append(temp)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 272859/272859 [00:31<00:00, 8609.93it/s]

# %%
f = open('./VAERS22/Questions.json', 'r')
zkp_q = json.load(f)

# %%
zkq_query = []
for x in zkp_q: 
    temp = {}
    temp['question'] = x['Question']
    if x['Field'] == 'PRIOR_VAX': 
        temp['query'] = '1'
    else: 
        temp['query'] = '3'
    zkq_query.append(temp)

# %%
query_all = query_q + zkq_query

# %%
f = open('./VAERS22/nl_22.json')
data = json.load(f)
questions22 =data['en']

# %%
query_dict = {}
for x in query_all:
    if x['question'] in query_dict.keys():
        print("------------------------------------")
        print("1. ",x['question'], ": ", query_dict[x['question']])
        print("2. ",x['question'], ": ", x['query'])
    else: 
        query_dict[x['question']] = x['query']
# Out:
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.  nan :  2
# 2.  nan :  2
# ------------------------------------
# 1.   How many people have been injected with 2 :  1
# 2.   How many people have been injected with 2 :  1
# ------------------------------------
# 1.   How many people have been injected with UNK :  1
# 2.   How many people have been injected with UNK :  1
# ------------------------------------
# 1.   How many people have been injected with 1 :  1
# 2.   How many people have been injected with 1 :  1
# ------------------------------------
# 1.   How many people have been injected with 3 :  1
# 2.   How many people have been injected with 3 :  1
# ------------------------------------
# 1.   How many people have been injected with 4 :  1
# 2.   How many people have been injected with 4 :  1
# ------------------------------------
# 1.   How many people have been injected with 5 :  1
# 2.   How many people have been injected with 5 :  1

# %%
out_query_qs = []
for x in questions22:
    temp = {}
    temp['question'] = x
    if x not in query_dict.keys():
        temp['query'] = '4'
    else:
        temp['query'] = query_dict[x]
    out_query_qs.append(temp)

# %%
len(out_query_qs)
# Out:
# 11283

# %%
f = open('./VAERS22/query22.json', 'w')
json.dump(out_query_qs, f)
f.close()

# %% [markdown]
# ### Save file

# %%
list(set([x['Field'] for x in zkp_q]))
# Out:
# ['ALLERGIES', 'CUR_ILL', 'LAB_DATA', 'HISTORY', 'OTHER_MEDS', 'PRIOR_VAX']

# %%
key_frq = {}
for x in zkp_q:
    if x['Field'] not in key_frq.keys():
        key_frq[x['Field']] = 1
    else: 
        cnt = key_frq[x['Field']]
        cnt +=1
        key_frq[x['Field']] = cnt

# %%
key_frq
# Out:
# {'ALLERGIES': 300,
#  'LAB_DATA': 300,
#  'OTHER_MEDS': 300,
#  'CUR_ILL': 400,
#  'HISTORY': 400,
#  'PRIOR_VAX': 300}

# %%
def key_list(var_name):
    out = []
    for x in zkp_q: 
        if x['Field'] == var_name:
            out.append(x['Question'])
    return out

# %%
ALLERGIES = key_list('ALLERGIES')
CUR_ILL = key_list('CUR_ILL')
LAB_DATA = key_list('LAB_DATA')
HISTORY = key_list('HISTORY')
OTHER_MEDS = key_list('OTHER_MEDS')
priorVax = key_list('PRIOR_VAX')

# %%
priorVax
# Out:
# ['Give me all the patients who got 4/11/21 before. ',
#  'Give me all the patients who got 2003/2011/2014 before. ',
#  'Give me all the patients who got 5/30/2021 before. ',
#  'Give me all the patients who got 2/2/21 before. ',
#  ' Give me all the patients who had a 6/11/2021 vaccine previously. ',
#  ' Give me all the patients who had a 12/18/2020 vaccine previously. ',
#  ' Give me all the patients who had a 05/06/2021 vaccine previously. ',
#  ' Give me all the patients who had a 9/14/1998 vaccine previously. ',
#  ' Give me all the patients who had a 3/19/21 vaccine previously. ',
#  ' Give me all the patients who had a 01/03/2022 vaccine previously. ',
#  ' Give me all the patients who had a 08/10/2018 vaccine previously. ',
#  ' Give me all the patients who had a 3/17/2021 vaccine previously. ',
#  ' Give me all the patients who had a 02/15/2021 vaccine previously. ',
#  ' Give me all the patients who had a 3/26/21 vaccine previously. ',
#  ' Give me all the patients who had a 11/09/2009 vaccine previously. ',
#  ' Give me all the patients who had a 03/30/2021 vaccine previously. ',
#  ' Give me all the patients who had a 1/6/2021 vaccine previously. ',
#  ' Give me all the patients who had a 2/8/2021 vaccine previously. ',
#  ' Give me all the patients who had a 3/31/2021 vaccine previously. ',
#  ' Give me all the patients who had a 7/14/21 vaccine previously. ',
#  ' Give me all the patients who had a 09/02/21 vaccine previously. ',
#  ' Give me all the patients who had a 3/27/21 vaccine previously. ',
#  ' Give me all the patients who had a 1/26/22 vaccine previously. ',
#  ' Give me all the patients who had a 08/06/2021 vaccine previously. ',
#  ' Give me all the patients who had a 04/28/2021 vaccine previously. ',
#  ' Give me all the patients who had a 03/21/2022 vaccine previously. ',
#  ' Give me all the patients who had a 4/15/21 vaccine previously. ',
#  ' Give me all the patients who had a 2/25/2021 vaccine previously. ',
#  ' Give me all the patients who had a 10/21/2021 vaccine previously. ',
#  ' Give me all the patients who had a 10/23/2021 vaccine previously. ',
#  ' Give me all the patients who had a 2/10/21 vaccine previously. ',
#  ' Give me all the patients who had a 6/13/2021 vaccine previously. ',
#  ' How many patients got 9/11/21 before?',
#  ' How many patients got 4/25/2021 before?',
#  ' How many patients got 5/01/21 before?',
#  ' How many patients got 7/1/21 before?',
#  ' How many patients got 01/12/2022 before?',
#  ' How many patients got 04/02/2021 before?',
#  ' How many patients got 6/11/21 before?',
#  ' How many patients got 5/22/21 before?',
#  ' How many patients got 09/18/2021 before?',
#  ' How many patients got 1/12/22 before?',
#  ' How many patients got 03/02/2021 before?',
#  ' How many patients got 2/25/19 before?',
#  ' How many patients got 10/24/2021 before?',
#  ' How many patients got 04/14/2021 before?',
#  ' How many patients got 02/28/21 before?',
#  ' How many patients got 03/14/2021 before?',
#  ' How many patients got 01/27/2021 before?',
#  ' How many patients got 07/20/21 before?',
#  ' How many patients got 11/27/18 before?',
#  ' How many patients got 3/5/2021 before?',
#  ' How many patients got 4/30/21 before?',
#  ' How many patients got 09/03/2021 before?',
#  ' How many patients got 3/28/2021 before?',
#  ' How many patients got 4/18/21 before?',
#  ' How many patients got 8/12/21 before?',
#  ' How many patients got 05/07/2021 before?',
#  ' How many patients got 03/15/2015 before?',
#  ' How many patients got 12/11/2021 before?',
#  ' How many patients got 5/12/21 before?',
#  ' How many patients got 5/27/2021 before?',
#  ' How many patients got 4/01/2021 before?',
#  ' How many patients got 4/20/21 before?',
#  ' How many patients got 03/15/2021 before?',
#  ' How many patients got 04/21/21 before?',
#  ' How many patients got 9/24/21 before?',
#  ' How many patients got 7/2/2019 before?',
#  ' How many patients got 01/07/2021 before?',
#  ' How many patients got 1/08/21 before?',
#  ' How many patients got 12/5/2016 before?',
#  ' How many patients got 6/10/21 before?',
#  ' How many patients got 12/13/21 before?',
#  ' How many patients got 04/15/21 before?',
#  ' How many patients got 03/29/2021 before?',
#  ' How many patients got 4/23/2021 before?',
#  ' How many patients got 1/23/2021 before?',
#  ' How many patients got 8/25/2021 before?',
#  ' How many patients got 8/28/21 before?',
#  ' How many patients got 03/30/21 before?',
#  ' How many patients got 01/23/2021 before?',
#  ' How many patients got 4/9/21 before?',
#  ' How many patients got 05/16/2021 before?',
#  ' How many patients got 07/23/2021 before?',
#  ' How many patients got 01/07/2022 before?',
#  ' How many patients got 5/18/2021 before?',
#  ' How many patients got 09/21/2021 before?',
#  ' How many patients got 03/13/21 before?',
#  ' How many patients got 02/16/21 before?',
#  ' How many patients got 5/15/21 before?',
#  ' How many patients got 3/11/22 before?',
#  ' How many patients got 02/21/2021 before?',
#  ' How many patients got 3/11/2021 before?',
#  ' How many patients got 10/14/2021 before?',
#  ' How many patients got 03/10/2021 before?',
#  ' How many patients got 12/22/2020 before?',
#  ' How many patients got 2/04/2021 before?',
#  ' How many patients got 9/19/2021 before?',
#  ' How many patients got 06/03/2021 before?',
#  ' How many patients got 5/11/21 before?',
#  ' How many patients got 12/19/20 before?',
#  ' How many patients got 1/4/21 before?',
#  ' How many patients got 01/20/21 before?',
#  ' How many patients got 3/8/21 before?',
#  ' How many patients got 04/09/2021 before?',
#  ' How many patients got 7/23/21 before?',
#  ' How many patients got 12/29/2020 before?',
#  ' How many patients got 02/28/2021 before?',
#  ' How many patients got 10/11/2012 before?',
#  ' How many patients got 04/08/2021 before?',
#  ' How many patients got 3/7/16 before?',
#  ' How many patients got 9/29/2009 before?',
#  ' How many patients got 2/6/21 before?',
#  ' How many patients got 08/21/2022 before?',
#  ' How many patients got 2/2/2021 before?',
#  ' How many patients got 08/27/21 before?',
#  ' How many patients got 7/13/21 before?',
#  ' How many patients got 6/10/2021 before?',
#  ' How many patients got 08/21/2021 before?',
#  ' How many patients got 3/10/2022 before?',
#  ' How many patients got 12/8/2021 before?',
#  ' How many patients got 04/22/2021 before?',
#  ' How many patients got 2/01/21 before?',
#  ' How many patients got 4/28/22 before?',
#  ' How many patients got 4/27/21 before?',
#  ' How many patients got 8/24/21 before?',
#  ' How many patients got 3/24/2021 before?',
#  ' How many patients got 04/22/2022 before?',
#  ' How many patients got 3/7/2021 before?',
#  ' How many patients got 02/04/2021 before?',
#  ' How many patients got 03/20/2021 before?',
#  ' How many patients got 1/29/21 before?']

# %%
q1 = list(questions.values())
q2 = [x['Question'] for x in temp]

# %%
out = q1 + q2

# %%
fout = open('questions22.json', "w")
json.dump(out, fout)
fout.close()

# %%
tokens = {'tokens': df.Tokens.tolist()}

# %%
fout = open("bio2021.json", "w")
json.dump(tokens, fout)
fout.close()
